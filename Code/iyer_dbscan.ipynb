# %%
library(ggplot2)

# %%
data=read.csv("iyer.csv")

# %%
df=as.data.frame(data)

# %%
df <- subset(df, select = -c(X) )
df$X2 <- gsub("b" ,"", df$X2)
df
# Out:
#     X0           X1          X2
# 1   -2.119342    0.9611317   1
# 2   -1.489251    0.5057986   1
# 3   -1.454628    0.7213953   1
# 4   -1.723843    0.9064059   1
# 5   -1.489775    0.6832764   1
# 6   -1.251943    0.7817673   1
# 7   -1.269829    0.9477472   1
# 8   -1.008643    1.0218943   1
# 9   -1.502422    0.9831167   1
# 10  -1.765631    1.2252817   1
# 11  -1.729213    1.2553513   1
# 12  -1.474043    1.0919138   1
# 13  -1.941017    0.9866621   1
# 14  -2.107679    1.0691449   1
# 15  -2.089010    1.0554104   1
# 16  -1.877794    0.8167372   1
# 17  -1.971503    0.9483761   1
# 18  -1.469195    0.8180913   1
# 19  -2.310798    1.2159621   1
# 20  -2.164590    1.1312722   1
# 21  -1.987289    1.1051398   1
# 22  -2.038613    1.1205481   1
# 23  -1.838663    0.9995952   1
# 24  -1.861457    0.8899283   1
# 25  -1.939911    0.9772276   1
# 26  -1.337241    0.8050224   1
# 27  -1.616939    0.8832857   1
# 28  -1.546180    0.8268974   1
# 29  -1.963165    0.7523261   1
# 30  -1.916453    0.6454914   1
# ⋮   ⋮            ⋮           ⋮
# 488  3.256900327 -0.05082450 0
# 489  3.699078585  0.20860665 0
# 490  3.176095382  0.13248610 0
# 491 34.872134280 -1.00489289 0
# 492  6.658387681 -7.32998073 0
# 493  0.505474581 -1.22276550 0
# 494  1.103352257 -0.65239160 0
# 495  1.096694773  0.33856105 0
# 496 -0.001780761  0.21744805 1
# 497 -0.401588762 -0.04430232 1
# 498  1.079954526  0.30237493 0
# 499 -1.301386730  0.95499671 1
# 500 -0.040068026  0.66507312 0
# 501  2.684302661  1.42114830 0
# 502 -0.095528413  0.96410016 0
# 503  2.763122347  0.90277558 0
# 504  2.106362831  0.72344999 0
# 505  0.970960395  0.51925355 0
# 506  3.898438258  1.33566024 0
# 507  3.538715343  0.43308674 0
# 508  4.311431591  0.14617440 0
# 509 16.502675920  1.27822319 0
# 510  1.150423956 -0.63703837 0
# 511  1.545762211 -0.30009930 0
# 512  0.837462568  0.12618849 0
# 513  2.762356233 -0.35732369 0
# 514  4.478523308 -1.08418909 0
# 515  4.305717795 -1.46705262 0
# 516  4.911680789 -1.15431024 0
# 517  5.793246000 -0.48432392 0

# %%
png('iyer_dbscan.png')
ggplot(df, aes(y=df$X1, x=df$X0, color=df$X2)) + scale_x_continuous("Principal_Component1") +
  scale_y_continuous("Principal_Component2") +
  ggtitle("PCA Plot")+labs(colour="Cluster")+
    geom_point(size=2, alpha=0.6)
dev.off()
# Out:
# png
#   2
