# %%
library(ggplot2)

# %%
data=read.csv("cho_kmeans.csv")

# %%
df=as.data.frame(data)

# %%
df <- subset(df, select = -c(X) )
df$X2 <- gsub("b" ,"", df$X2)
df
# Out:
#     X0          X1          X2
# 1    0.64593175  1.6419131  1
# 2   -1.03856991  0.7455622  0
# 3    0.05900250  1.1513088  1
# 4    1.14847720  1.0452188  4
# 5    0.83448935  0.6385899  4
# 6    1.96652019  1.4170331  4
# 7    0.80838102  0.5439514  4
# 8    0.57484112  0.6290503  4
# 9    0.64539928  1.3789830  4
# 10   1.08023033  0.4983811  4
# 11   0.33144357  1.8752708  1
# 12   2.52454989  1.8497722  2
# 13   1.03607285  1.9946093  1
# 14   1.06054031  2.1265333  1
# 15   0.54800078  2.3494694  1
# 16   0.97184068  1.1259534  1
# 17   0.94944226  0.6426314  1
# 18   0.48398909  1.1381433  1
# 19  -0.40378390  1.4871038  1
# 20   1.00131864  0.9393662  1
# 21  -0.01851839  1.8187585  1
# 22   1.04460962  0.6323909  1
# 23  -0.19921704  2.1782968  1
# 24   0.82854511  1.1287207  1
# 25  -0.65591460 -0.4127166  0
# 26  -1.00247145  0.6992114  4
# 27   0.81921332  1.1826420  1
# 28  -1.88713267 -0.6224161  0
# 29   0.09301532  0.1542165  4
# 30   3.84765481  1.7477636  2
# ...

# %%
#png('KmeansNEW_Plot_iyer.jpg')

ggplot(df, aes(y=df$X1, x=df$X0, color=df$X2)) + scale_x_continuous("Principal_Component1") +
  scale_y_continuous("Principal_Component2") +
  ggtitle("PCA Plot")+labs(colour="Cluster")+
    geom_point(size=2, alpha=0.6)

#dev.off()
# Out:
# plot without title
