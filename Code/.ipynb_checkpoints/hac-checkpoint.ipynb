# %%
library(ggplot2)

# %%
data=read.csv("newdset_hac_3.csv")

# %%
df=as.data.frame(data)

# %%
df <- subset(df, select = -c(X) )
df$X2 <- gsub("b" ,"", df$X2)
df
# Out:
#     X0          X1          X2
# 1   -2.204508   1.2024313   7
# 2   -1.552872   0.7385078   7
# 3   -1.546893   1.0829922   7
# 4   -1.798502   1.1153085   7
# 5   -1.568234   0.9597867   7
# 6   -1.354142   1.1797776   7
# 7   -1.371171   1.3293234   7
# 8   -1.107684   1.3765458   7
# 9   -1.595363   1.2946290   7
# 10  -1.855154   1.4519189   7
# 11  -1.831408   1.5591709   7
# 12  -1.563019   1.3528913   7
# 13  -2.032691   1.2670547   7
# 14  -2.214157   1.4173497   7
# 15  -2.171715   1.2511133   7
# 16  -1.941417   0.9603829   7
# 17  -2.055846   1.1793653   7
# 18  -1.541571   1.0146180   7
# 19  -2.407135   1.4659908   7
# 20  -2.248988   1.3347999   7
# 21  -2.065829   1.2859538   7
# 22  -2.137266   1.4103886   7
# 23  -1.923500   1.2410663   7
# 24  -1.937977   1.1027898   7
# 25  -2.020962   1.1864972   7
# 26  -1.402754   0.9698303   7
# 27  -1.699611   1.1298758   7
# 28  -1.604009   0.9489546   7
# 29  -2.045176   1.0064058   7
# 30  -1.988036   0.8701686   7
# ⋮   ⋮           ⋮           ⋮
# 488  3.23185178  0.20488650 9
# 489  3.65626973  0.53327067 9
# 490  3.19809005  0.05068977 9
# 491 35.36222045 -2.50077499 5
# 492  6.99910283 -7.48834719 1
# 493  0.62371422 -1.65980044 6
# 494  1.11328800 -0.49696497 8
# 495  1.01383599  0.85176368 4
# 496 -0.07744588  0.65862470 4
# 497 -0.48035970  0.46047178 4
# 498  1.03286360  0.58344373 8
# 499 -1.36156997  1.08387756 7
# 500 -0.11370986  0.96770822 4
# 501  2.60361707  1.69297685 8
# 502 -0.16770131  1.20958613 4
# 503  2.71273722  1.12036829 8
# 504  2.03671845  1.08147441 8
# 505  0.91178858  0.82028551 4
# 506  3.84789320  1.48900166 8
# 507  3.45998709  0.96682914 9
# 508  4.23894592  0.74843718 9
# 509 16.36016977  2.57106926 5
# 510  1.10923996 -0.16157093 8
# 511  1.48690063  0.21411529 8
# 512  0.83430403  0.15093464 4
# 513  2.77618118 -0.26355903 8
# 514  4.53687640 -1.03539263 8
# 515  4.36826438 -1.34298402 8
# 516  4.92751914 -0.81675341 8
# 517  5.75114484  0.09822077 8

# %%
png('HAC_Plot_NEW.jpg')
ggplot(df, aes(y=df$X1, x=df$X0, color=df$X2)) + scale_x_continuous("Principal_Component1") +
  scale_y_continuous("Principal_Component2") +
  ggtitle("PCA Plot")+labs(colour="Cluster")+
    geom_point(size=2, alpha=0.6)
#dev.off()
# Out:
# plot without title
